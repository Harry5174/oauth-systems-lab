# %% [markdown]
# # Minimal OAuth Authorization Code Flow (Pure Python)
#
# This notebook simulates the OAuth 2.0 Authorization Code flow
# using pure Python functions.
#
# Goals:
# - Understand execution order
# - See where invariants are enforced
# - Avoid framework abstractions

# %% [markdown]
# ## Actors (Conceptual Mapping)
#
# - Client (Agent): initiates flow
# - Authorization Server: validates and issues tokens
# - Resource Server: validates tokens only
#
# In this notebook, each actor is represented
# by a Python function.

# %%
# authorization server state (represents server side memory)
REGISTERED_REDIRECT_URIS = {
    "client-123": ["https://agent.example.com/callback"]
}

AUTHORIZATION_CODES = {}
ISSUED_TOKENS = {}

# %%
print(REGISTERED_REDIRECT_URIS.get("client-123", []))
# Out:
# ['https://agent.example.com/callback']

# %%
# utility function to enforce https
def require_https(url: str):
    assert url.startswith("https://"), "URL must be https"

def require_exact_uri(client_id: str, redirect_uri: str):
    allowed = REGISTERED_REDIRECT_URIS.get(client_id, [])
    assert redirect_uri in allowed, "redirect_uri mismatched"

# %%
# AUTHORIZATION_CODES["code"] = {
#     "client_id" : "example_client_id",
#     "redirect_uri" : "example_redirect_uri",
#     "code_challenge" : "example_code_challenge",
#     "scope" : "example_scope"
# # }
# import json

# print(json.dumps(AUTHORIZATION_CODES, indent=2) )
# Out:
# {
#   "code": {
#     "client_id": "example_client_id",
#     "redirect_uri": "example_redirect_uri",
#     "code_challenge": "example_code_challenge",
#     "scope": "example_scope"
#   }
# }

# %%
# Client → Authorization Server (/authorize) : Authorization Request (Code)

import secrets

def authorize_request(
    client_id: str,
    redirect_uri: str,
    scope: str,
    code_challenge: str
):
    # Invariants enforced here
    require_https(redirect_uri)
    require_exact_uri(client_id, redirect_uri)
    assert code_challenge, "PKCE required"
    
    # Issue authorization code
    code = secrets.token_urlsafe(16)
    
    AUTHORIZATION_CODES[code] = {
        "client_id" : client_id,
        "redirect_uri" : redirect_uri,
        "code_challenge" : code_challenge,
        "scope" : scope
    }
    
    return code

# %%
# Client → Authorization Server (/token) : Token Exchange (Code)

import hashlib
import base64

def s256(verifier: str)-> str:
    digest = hashlib.sha256(verifier.encode()).digest()
    return base64.urlsafe_b64encode(digest).rstrip(b'=').decode('ascii')


def token_request(
    code: str,
    client_id: str,
    redirect_uri: str,
    code_verifier: str
):
    record = AUTHORIZATION_CODES.pop(code, None)
    assert record, "invalid authorization code"

    assert record["client_id"] == client_id
    assert record["redirect_uri"] == redirect_uri

    # PKCE check
    
    # print({
    #         "code_verifier" : code_verifier,
    #         "record[code_challenge]" : record["code_challenge"]  (for debugging)
    #         })
    
    assert s256(code_verifier) == record["code_challenge"], "PKCE failed"

    token = secrets.token_urlsafe(24)
    ISSUED_TOKENS[token] = {
        "client_id": client_id,
        "scope": record["scope"]
    }

    return token

# %%
# Full happy-path simulation (Code)

# Client-side values
CLIENT_ID = "client-123"
REDIRECT_URI = "https://agent.example.com/callback"
SCOPE = "research.read"

# PKCE setup
code_verifier = "random-secret"
code_challenge = s256(code_verifier)

# Step 1: authorize
auth_code = authorize_request(
    CLIENT_ID,
    REDIRECT_URI,
    SCOPE,
    code_challenge
)

# Step 2: token
access_token = token_request(
    auth_code,
    CLIENT_ID,
    REDIRECT_URI,
    code_verifier
)

access_token
# Out:
# {'code_verifier': 'random-secret', 'record[code_challenge]': 'sk5IUKMvL6Zt0dxaeaTC182dE4poZyEJPWnXs8i-0OE'}
# '5pdUFbmNmPk3NHwThG3uKFLKF2pDxQ93'

# %%
# wrong examples (will yeild assertion errors)

authorize_request(
    CLIENT_ID,
    "https://evil.example.com/callback",
    SCOPE,
    code_challenge
)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 authorize_request(
#       2     CLIENT_ID,
#       3     "https://evil.example.com/callback",
#       4     SCOPE,
#       5     code_challenge
#       6 )
#
# Cell In[4], line 13, in authorize_request(client_id, redirect_uri, scope, code_challenge)
#       5 def authorize_request(
#       6     client_id: str,
#       7     redirect_uri: str,
#    (...)     10 ):
#      11     # Invariants enforced here
#      12     require_https(redirect_uri)
# ---> 13     require_exact_uri(client_id, redirect_uri)
#      14     assert code_challenge, "PKCE required"
#      16     # Issue authorization code
#
# Cell In[9], line 7, in require_exact_uri(client_id, redirect_uri)
#       5 def require_exact_uri(client_id: str, redirect_uri: str):
#       6     allowed = REGISTERED_REDIRECT_URIS.get(client_id, [])
# ----> 7     assert redirect_uri in allowed, "redirect_uri mismatched"
#
# AssertionError: redirect_uri mismatched

# %%
bad_verifier = "attacker-secret"

token_request(
    auth_code,
    CLIENT_ID,
    REDIRECT_URI,
    bad_verifier
)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[17], line 3
#       1 bad_verifier = "attacker-secret"
# ----> 3 token_request(
#       4     auth_code,
#       5     CLIENT_ID,
#       6     REDIRECT_URI,
#       7     bad_verifier
#       8 )
#
# Cell In[13], line 18, in token_request(code, client_id, redirect_uri, code_verifier)
#      11 def token_request(
#      12     code: str,
#      13     client_id: str,
#      14     redirect_uri: str,
#      15     code_verifier: str
#      16 ):
#      17     record = AUTHORIZATION_CODES.pop(code, None)
# ---> 18     assert record, "invalid authorization code"
#      20     assert record["client_id"] == client_id
#      21     assert record["redirect_uri"] == redirect_uri
#
# AssertionError: invalid authorization code
